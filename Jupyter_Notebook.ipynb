# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Peer-graded Assignment</h1>

# %% [markdown]
# Introduction related to Data Science's tools, enviroments and languages.

# %% [markdown]
# Popular langueges used in Data Science
# 1. Pyhon
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++

# %% [markdown]
# Popular libraries in Data Science
# 1. Pandas
# 2. Numpy
# 3. Seaborn
# 4. Pytorch
# 5. Apache Spark
# 6. Scikit-learn

# %% [markdown]
# | Tool           | Description                        |
# |----------------|----------------------------------|
# | Jupyter Notebook | Kernel based computing enviroment |
# | R Studio    | R based enviroment               |
# | GitHub          | Tool for version and colaboration control |
# | GoogleColab    | Web notebook               |

# %% [markdown]
# <h3>Arithmetic Expressions exemplas on Python Lab

# %%
#Defining variables and executing sum and mult, after the results
a = 2
b = 12
sum = a + b
product = a * b

sum, product
# Out:
# (14, 24)

# %%
#Conversion of minutos to hours, 120 minutes
minutes = 180

hours = minutes / 60

hours
# Out:
# 3.0

# %% [markdown]
# <h3>Objectives:</h3>
#
# - Introduction of the basic data science languages, libraries and features
# - Introduction of Jupyter Lab, R studio and Git Hub
# - Aritmethics operations

# %% [markdown]
# <h2>Author:</h2>
#
# - Hugo Guimarães Martins
