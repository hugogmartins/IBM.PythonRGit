# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# TITLE : Peer-graded Assignment

# %% [markdown]
# Introduction

# %% [markdown]
# Science Languages:
# Python; R; Julia; Scala; SQL

# %% [markdown]
# Libraries: Pandas; NumPy; Scikit-Learn; Tensor-Flow; Keras

# %% [markdown]
# | Tool           | Description                        |
# |----------------|----------------------------------|
# | Jupyter Notebook | Kernel based computing enviroment |
# | R Studio    | R based enviroment               |
# | GitHub          | Tool for version and colaboration control |
# | GoogleColab    | Web notebook               |

# %% [markdown]
# Exercise 7 : Arithmetic Expressions exemples

# %%
a = 2
b = 12
sum = a + b
product = a * b

sum, product
# Out:
# (14, 24)

# %%
minutes = 180

hours = minutes / 60

hours
# Out:
# 3.0

# %% [markdown]
# Exercise 10 : Insert a markdown cell to list objectives
#
# - Introduction of the basic data science languages, libraries and features
# - Introduction of Jupyter Lab, R studio and Git Hub

# %% [markdown]
# Exercise 11 : Crate a marksown cell to indicate the author's name
#
# - Hugo Guimarães Martins
